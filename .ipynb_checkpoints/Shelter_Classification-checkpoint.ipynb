# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame, Series
import re
# %matplotlib inline

# %%
df = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
sample = pd.read_csv('data/sample_submission.csv')

# %% [markdown]
# ## NaN 값 처리

# %%
df['Name'] = df['Name'].replace(np.nan, 'Unnamed', regex=True)
df['AgeuponOutcome'] = df['AgeuponOutcome'].replace(np.nan, '0 days', regex=True)
df['OutcomeSubtype'] = df['OutcomeSubtype'].replace(np.nan, 'None', regex=True)
df['SexuponOutcome'] = df['SexuponOutcome'].replace(np.nan, 'Unknown', regex=True)

# %%
for i in range(0, len(df['Name'])):
    if df['Name'][i] != 'Unnamed':
        df['Name'][i] = 'Named'

# %% [markdown]
# ## 나이 단위를 일(day)로 통일

# %%
for i in range(0, len(df['AgeuponOutcome'])):
    num, unit = (df['AgeuponOutcome'][i]).split(' ')
    if unit == 'year' or unit == 'years':
        df['AgeuponOutcome'][i] = int(num) * 365
    elif unit == 'month' or unit == 'months':
        df['AgeuponOutcome'][i] = int(num) * 30
    elif unit == 'week' or unit == 'weeks':
        df['AgeuponOutcome'][i] = int(num) * 7
    elif unit == 'day' or unit == 'days':
        df['AgeuponOutcome'][i] = int(num)

# %%
df['AgeuponOutcome'] = df['AgeuponOutcome'].astype(int)
df['OutcomeType'] = df['OutcomeType'].astype(str)

# %% [markdown]
# ## 더미화

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['Name'] = encoder.fit_transform(df['Name'])
df['SexuponOutcome'] = encoder.fit_transform(df['SexuponOutcome'])
df['SexuponOutcome'] = encoder.fit_transform(df['SexuponOutcome'])

# %%
Dog = df[df['AnimalType'] == 'Dog']
Cat = df[df['AnimalType'] == 'Cat']

# %%
Dog.head()
# Out:
#   AnimalID  Name             DateTime      OutcomeType OutcomeSubtype  \
# 0  A671945     0  2014-02-12 18:22:00  Return_to_owner           None
# 2  A686464     0  2015-01-31 12:28:00         Adoption         Foster
# 4  A667013     1  2013-11-15 12:52:00         Transfer        Partner
# 5  A677334     0  2014-04-25 13:04:00         Transfer        Partner
# 8  A671784     0  2014-02-04 17:17:00         Adoption           None
#
#   AnimalType  SexuponOutcome  AgeuponOutcome  \
# 0        Dog               2             365
# 2        Dog               2             730
# 4        Dog               2             730
# 5        Dog               0              30
# 8        Dog               3             150
#
#                                Breed        Color
# 0              Shetland Sheepdog Mix  Brown/White
# 2                       Pit Bull Mix   Blue/White
# 4        Lhasa Apso/Miniature Poodle          Tan
# 5  Cairn Terrier/Chihuahua Shorthair    Black/Tan
# 8      American Pit Bull Terrier Mix    Red/White

# %% [markdown]
# ## 분류나무 실행

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=3)

# %%
X = Dog[['Name', 'SexuponOutcome', 'AgeuponOutcome']]
Y = Dog['OutcomeType']

# %%
clf = clf.fit(X, Y)

# %%
clf.score(X, Y)
# Out:
# 0.5356203911510099

# %%
clf_X = Dog[['AnimalType', 'SexuponOutcome', 'AgeuponOutcome']]

# %%
from IPython.display import Image
from sklearn import tree
import pydotplus 
import graphviz

# %%
dot_data = tree.export_graphviz(clf, out_file=None, filled=True, rounded=True, special_characters=True,
                               feature_names=['AnimalType', 'SexuponOutcome', 'AgeuponOutcome'],
                               class_names=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x000001C4E59C3D68>>
# Traceback (most recent call last):
#   File "c:\python3\lib\site-packages\xgboost-0.6-py3.6.egg\xgboost\core.py", line 343, in __del__
#     _check_call(_LIB.XGDMatrixFree(self.handle))
# AttributeError: 'DMatrix' object has no attribute 'handle'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, filled=True, rounded=True, special_characters=True,
                               feature_names=clf_X,
                               class_names=Dog.OutcomeType)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-5793d4c835eb> in <module>()
#       1 dot_data = tree.export_graphviz(clf, out_file=None, filled=True, rounded=True, special_characters=True,
#       2                                feature_names=clf_X,
# ----> 3                                class_names=Dog.OutcomeType)
#       4 graph = pydotplus.graph_from_dot_data(dot_data)
#       5 Image(graph.create_png())
#
# c:\python3\lib\site-packages\sklearn\tree\export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters)
#     431             recurse(decision_tree, 0, criterion="impurity")
#     432         else:
# --> 433             recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
#     434
#     435         # If required, draw leaf nodes at same depth as each other
#
# c:\python3\lib\site-packages\sklearn\tree\export.py in recurse(tree, node_id, criterion, parent, depth)
#     319             out_file.write('%d [label=%s'
#     320                            % (node_id,
# --> 321                               node_to_str(tree, node_id, criterion)))
#     322
#     323             if filled:
#
# c:\python3\lib\site-packages\sklearn\tree\export.py in node_to_str(tree, node_id, criterion)
#     217             # Always write node decision criteria, except for leaves
#     218             if feature_names is not None:
# --> 219                 feature = feature_names[tree.feature[node_id]]
#     220             else:
#     221                 feature = "X%s%s%s" % (characters[1],
#
# c:\python3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# c:\python3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# c:\python3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# c:\python3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# c:\python3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 1

# %% [markdown]
# ## Bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bagging = BaggingClassifier(DecisionTreeClassifier())

# %%
bagging.fit(X, Y)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=10, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)

# %%
bagging.predict
# Out:
# <bound method BaggingClassifier.predict of BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=10, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)>

# %%
bagging.score(X, Y)
# Out:
# 0.57691567810195576

# %% [markdown]
# ## XGBoost

# %%
var = Dog[['Name', 'SexuponOutcome', 'AgeuponOutcome']]

# %%
var['AgeuponOutcome'] = var['AgeuponOutcome'].astype(int)
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Dog['OutcomeTypedum'] = encoder.fit_transform(Dog['OutcomeType'])
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
import xgboost as xgb

# %%
xgbr = xgb.XGBRegressor(n_estimators=100)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(var, Dog.OutcomeTypedum, test_size=0.25)

# %%
xgbr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_train, xgbr.predict(X_train))
# Out:
# 2.2534488127504733

# %%
y_pred = xgbr.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 2.2677244007015429

# %%
xgb.plot_importance(xgbr)

# %%
xgb.to_graphviz(xgbr, num_trees=0)
